# %%
import os
import certifi

# Fix SSL certificate verification for Windows
os.environ['SSL_CERT_FILE'] = certifi.where()
os.environ['REQUESTS_CA_BUNDLE'] = certifi.where()

# %%
# %pip install certifi
# %pip install serpapi
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from reaserch_crew import ResearchCrew
from research_output import ResearchFindingJSONOutput
import json

research_crew = ResearchCrew()
results = research_crew.crew().kickoff(inputs={"topic": "latest advancements in artificial intelligence"})

# The results.pydantic will contain the structured output from the summarization task
print("=" * 50)
print("STRUCTURED OUTPUT (JSON):")
print("=" * 50)

# Check if we have pydantic output
if hasattr(results, 'pydantic') and results.pydantic:
    structured_output = results.pydantic.dict()
    print(json.dumps(structured_output, indent=2))
else:
    # Fallback to raw output
    print("\nRaw Output:")
    print(results.raw)
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Internet Researcher                                                                                     │
# │                                                                                                                 │
# │  Task: Use the SerperDevTool to find the most relevant and  recent data on latest advancements in artificial    │
# │  intelligence.                                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ...
